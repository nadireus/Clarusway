# %% [markdown]
# <a href="https://colab.research.google.com/github/nadireus/Clarusway/blob/main/Project___DV_capstone_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to **"Bike Demand Visualization Project"** which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
#
#
#
# #### Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# **"weather_code" category description:**
# * 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# * 2 = scattered clouds / few clouds
# * 3 = Broken clouds
# * 4 = Cloudy
# * 7 = Rain/ light Rain shower/ Light rain
# * 10 = rain with thunderstorm
# * 26 = snowfall
# * 94 = Freezing Fog
# ---
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc.  Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.

# %% [markdown]
# # Tasks

# %% [markdown]
# ### 1.Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.Read dataset

# %%
df=pd.read_csv("store_sharing.cvs",encoding="windows-1252")

# %%
df.head()
# Out:
#              timestamp  cnt   t1  ...  is_holiday  is_weekend  season
# 0  2015-01-04 00:00:00  182  3.0  ...         0.0         1.0     3.0
# 1  2015-01-04 01:00:00  138  3.0  ...         0.0         1.0     3.0
# 2  2015-01-04 02:00:00  134  2.5  ...         0.0         1.0     3.0
# 3  2015-01-04 03:00:00   72  2.0  ...         0.0         1.0     3.0
# 4  2015-01-04 04:00:00   47  2.0  ...         0.0         1.0     3.0
#
# [5 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df.shape
# Out:
# (17414, 10)

# %%
df.describe()
# Out:
#                 cnt            t1  ...    is_weekend        season
# count  17414.000000  17414.000000  ...  17414.000000  17414.000000
# mean    1143.101642     12.468091  ...      0.285403      1.492075
# std     1085.108068      5.571818  ...      0.451619      1.118911
# min        0.000000     -1.500000  ...      0.000000      0.000000
# 25%      257.000000      8.000000  ...      0.000000      0.000000
# 50%      844.000000     12.500000  ...      0.000000      1.000000
# 75%     1671.750000     16.000000  ...      1.000000      2.000000
# max     7860.000000     34.000000  ...      1.000000      3.000000
#
# [8 rows x 9 columns]

# %%
df.describe(include='O')
# Out:
#                   timestamp
# count                 17414
# unique                17414
# top     2016-06-16 05:00:00
# freq                      1

# %% [markdown]
# ### 3.Check missing values and if there are any dublicate rows or not.

# %%
df.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    17414
# dtype: int64

# %%
df.isnull().value_counts()
# Out:
# timestamp  cnt    t1     t2     hum    wind_speed  weather_code  is_holiday  is_weekend  season
# False      False  False  False  False  False       False         False       False       False     17414
# dtype: int64

# %% [markdown]
# ### 4.Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)

# %%
plt.figure(figsize=[6,4])
sns.countplot(df.season)
plt.xlabel('season')
plt.ylabel('count')
plt.title('distribution of season')
# Out:
# Text(0.5, 1.0, 'distribution of season')

# %%
plt.figure(figsize=[6,4])
sns.countplot(df.is_holiday)
plt.xlabel('is_holiday')
plt.ylabel('count')
plt.title('distribution of is_holiday')
# Out:
# Text(0.5, 1.0, 'distribution of is_holiday')

# %%
plt.figure(figsize=[6,4])                         # is_weekend
sns.countplot(df.is_weekend)
plt.xlabel('is_weekend')
plt.ylabel('count')
plt.title('distribution of is_weekend')
# Out:
# Text(0.5, 1.0, 'distribution of is_weekend')

# %%
plt.figure(figsize=[6,4])                       # weather_code
sns.countplot(df.weather_code)
plt.xlabel('weather_code')
plt.ylabel('count')
plt.title('distribution of weather_code')
# Out:
# Text(0.5, 1.0, 'distribution of weather_code')

# %% [markdown]
# ### 5.Look at the data type of each variable, transform `timestamp` in type, and set it as index.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
#  10  timestamp1    17414 non-null  datetime64[ns]
#  11  hour          17414 non-null  object
#  12  year_month    17414 non-null  object
#  13  day_of-week   17414 non-null  object
#  14  dayname       17414 non-null  object
# dtypes: datetime64[ns](1), float64(8), int64(1), object(5)
# memory usage: 2.0+ MB

# %%
df['timestamp']=pd.to_datetime(df['timestamp'])

# %%
df['timestamp1']=df['timestamp']

# %%
df['timestamp1']=pd.to_datetime(df['timestamp1'])

# %%
df.set_index(['timestamp'], inplace=True)

# %% [markdown]
# - Tam 2 yillik bir timestamp var. `year, month, day_of_month, day_of_week, hour` bilgilerini alarak feature engineering yapalim

# %% [markdown]
# ### 6.Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)

# %% [markdown]
# you can use strftime('%Y-%m') for year_mount

# %%
df['timestamp1']=pd.to_datetime(df['timestamp1'])
df['hour']=df['timestamp1'].dt.hour
df['day_of-month'] = df['timestamp1'].dt.day 
df['day_of-week'] = df['timestamp1'].dt.dayofweek
df['year'] = df['timestamp1'].dt.year
df['month'] = df['timestamp1'].dt.month

# %% [markdown]
# # ***The  another solutions indicated below ***

# %%
df['hour2']= df.timestamp1.dt.strftime('%l %P')
df['hour2']

# %%
df['year'] = df['timestamp1'].dt.strftime('%Y')
df['year']
# Out:
# timestamp
# 2015-01-04 00:00:00    2015
# 2015-01-04 01:00:00    2015
# 2015-01-04 02:00:00    2015
# 2015-01-04 03:00:00    2015
# 2015-01-04 04:00:00    2015
#                        ...
# 2017-01-03 19:00:00    2017
# 2017-01-03 20:00:00    2017
# 2017-01-03 21:00:00    2017
# 2017-01-03 22:00:00    2017
# 2017-01-03 23:00:00    2017
# Name: year, Length: 17414, dtype: object

# %%
df['year']=df['year'].astype(str).astype(int)
df['year']
# Out:
# timestamp
# 2015-01-04 00:00:00    2015
# 2015-01-04 01:00:00    2015
# 2015-01-04 02:00:00    2015
# 2015-01-04 03:00:00    2015
# 2015-01-04 04:00:00    2015
#                        ...
# 2017-01-03 19:00:00    2017
# 2017-01-03 20:00:00    2017
# 2017-01-03 21:00:00    2017
# 2017-01-03 22:00:00    2017
# 2017-01-03 23:00:00    2017
# Name: year, Length: 17414, dtype: int64

# %%
df['year_month'] = df['timestamp1'].dt.strftime('%Y-%m')
df['year_month']
# Out:
# timestamp
# 2015-01-04 00:00:00    2015-01
# 2015-01-04 01:00:00    2015-01
# 2015-01-04 02:00:00    2015-01
# 2015-01-04 03:00:00    2015-01
# 2015-01-04 04:00:00    2015-01
#                         ...
# 2017-01-03 19:00:00    2017-01
# 2017-01-03 20:00:00    2017-01
# 2017-01-03 21:00:00    2017-01
# 2017-01-03 22:00:00    2017-01
# 2017-01-03 23:00:00    2017-01
# Name: year_month, Length: 17414, dtype: object

# %%
df['day_of-month'] = df['timestamp1'].dt.day 
df['day_of-month']
# Out:
# timestamp
# 2015-01-04 00:00:00    4
# 2015-01-04 01:00:00    4
# 2015-01-04 02:00:00    4
# 2015-01-04 03:00:00    4
# 2015-01-04 04:00:00    4
#                       ..
# 2017-01-03 19:00:00    3
# 2017-01-03 20:00:00    3
# 2017-01-03 21:00:00    3
# 2017-01-03 22:00:00    3
# 2017-01-03 23:00:00    3
# Name: day_of-month, Length: 17414, dtype: int64

# %%
df['monthname'] = df['timestamp1'].dt.to_period('M')

# %%
df['month_name'] = df['timestamp1'].dt.strftime('%B')
df['month_name']
# Out:
# timestamp
# 2015-01-04 00:00:00    January
# 2015-01-04 01:00:00    January
# 2015-01-04 02:00:00    January
# 2015-01-04 03:00:00    January
# 2015-01-04 04:00:00    January
#                         ...
# 2017-01-03 19:00:00    January
# 2017-01-03 20:00:00    January
# 2017-01-03 21:00:00    January
# 2017-01-03 22:00:00    January
# 2017-01-03 23:00:00    January
# Name: month_name, Length: 17414, dtype: object

# %%
df['day_of-week'] = df['timestamp1'].dt.dayofweek
df['day_of-week']
# Out:
# timestamp
# 2015-01-04 00:00:00    6
# 2015-01-04 01:00:00    6
# 2015-01-04 02:00:00    6
# 2015-01-04 03:00:00    6
# 2015-01-04 04:00:00    6
#                       ..
# 2017-01-03 19:00:00    1
# 2017-01-03 20:00:00    1
# 2017-01-03 21:00:00    1
# 2017-01-03 22:00:00    1
# 2017-01-03 23:00:00    1
# Name: day_of-week, Length: 17414, dtype: int64

# %%
df['day_of-week'] = df['timestamp1'].dt.strftime('%d') 
df['day_of-week'][:2]

# %%
df['day_of-week']=df['day_of-week'].astype(str).astype(int)
df['day_of-week']
# Out:
# timestamp
# 2015-01-04 00:00:00    4
# 2015-01-04 01:00:00    4
# 2015-01-04 02:00:00    4
# 2015-01-04 03:00:00    4
# 2015-01-04 04:00:00    4
#                       ..
# 2017-01-03 19:00:00    3
# 2017-01-03 20:00:00    3
# 2017-01-03 21:00:00    3
# 2017-01-03 22:00:00    3
# 2017-01-03 23:00:00    3
# Name: day_of-week, Length: 17414, dtype: int64

# %%
df['dayname'] = df['timestamp1'].dt.strftime('%A')
df['dayname']
# Out:
# timestamp
# 2015-01-04 00:00:00     Sunday
# 2015-01-04 01:00:00     Sunday
# 2015-01-04 02:00:00     Sunday
# 2015-01-04 03:00:00     Sunday
# 2015-01-04 04:00:00     Sunday
#                         ...
# 2017-01-03 19:00:00    Tuesday
# 2017-01-03 20:00:00    Tuesday
# 2017-01-03 21:00:00    Tuesday
# 2017-01-03 22:00:00    Tuesday
# 2017-01-03 23:00:00    Tuesday
# Name: dayname, Length: 17414, dtype: object

# %%
df.drop(columns=['timestamp1'], inplace=True)

# %%
df.head()
# Out:
#              timestamp  cnt   t1   t2  ...  month  year_month  dayname  month_name
# 0  2015-01-04 00:00:00  182  3.0  2.0  ...      1     2015-01   Sunday     January
# 1  2015-01-04 01:00:00  138  3.0  2.5  ...      1     2015-01   Sunday     January
# 2  2015-01-04 02:00:00  134  2.5  2.5  ...      1     2015-01   Sunday     January
# 3  2015-01-04 03:00:00   72  2.0  2.0  ...      1     2015-01   Sunday     January
# 4  2015-01-04 04:00:00   47  2.0  0.0  ...      1     2015-01   Sunday     January
#
# [5 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17414 entries, 2015-01-04 00:00:00 to 2017-01-03 23:00:00
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cnt           17414 non-null  int64
#  1   t1            17414 non-null  float64
#  2   t2            17414 non-null  float64
#  3   hum           17414 non-null  float64
#  4   wind_speed    17414 non-null  float64
#  5   weather_code  17414 non-null  float64
#  6   is_holiday    17414 non-null  float64
#  7   is_weekend    17414 non-null  float64
#  8   season        17414 non-null  float64
#  9   timestamp1    17414 non-null  datetime64[ns]
#  10  hour          17414 non-null  int64
#  11  day_of-month  17414 non-null  int64
#  12  day_of-week   17414 non-null  int64
#  13  year          17414 non-null  int64
#  14  month         17414 non-null  int64
#  15  year_month    17414 non-null  object
#  16  dayname       17414 non-null  object
# ...

# %% [markdown]
# ### 7.Visualize the correlation with a heatmap

# %%
import statistics as stat

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df.corr(), vmin = -1, vmax = 1, annot = True, cmap="coolwarm")

# %%
plt.figure(figsize=(2,8))
sns.heatmap(df.corr()[['cnt']] , vmin=-1, vmax=+1, annot=True, cmap='BrBG' )

# %%
cnt_corr=df.corr()[['cnt']].sort_values(by='cnt',ascending=False)

# %%
plt.figure(figsize=(2,8))
sns.heatmap(cnt_corr , vmin=-1, vmax=1, annot=True, cmap='BrBG' ) #ordered

# %% [markdown]
# ### 8. Visualize the correlation of the target variable and the other features with barplot

# %%
x=df.corr()['cnt'].sort_values(ascending=False).index
y=df.corr()['cnt'].sort_values(ascending=False).values

# %%
plt.figure(figsize=(12,5))
sns.barplot(y,x, color='b',order=x)

# %%
plt.figure(figsize=(12,5))
df.corr()['cnt'].sort_values().plot.barh();

# %% [markdown]
# ### 9.Plot bike shares over time use lineplot

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-04 00:00:00', '2015-01-04 01:00:00',
#                '2015-01-04 02:00:00', '2015-01-04 03:00:00',
#                '2015-01-04 04:00:00', '2015-01-04 05:00:00',
#                '2015-01-04 06:00:00', '2015-01-04 07:00:00',
#                '2015-01-04 08:00:00', '2015-01-04 09:00:00',
#                ...
#                '2017-01-03 14:00:00', '2017-01-03 15:00:00',
#                '2017-01-03 16:00:00', '2017-01-03 17:00:00',
#                '2017-01-03 18:00:00', '2017-01-03 19:00:00',
#                '2017-01-03 20:00:00', '2017-01-03 21:00:00',
#                '2017-01-03 22:00:00', '2017-01-03 23:00:00'],
#               dtype='datetime64[ns]', name='timestamp', length=17414, freq=None)

# %%
plt.figure(figsize=(15,9))
sns.lineplot( x=df.index, y='cnt',data=df)
plt.show()

# %% [markdown]
# ### 10.Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot)

# %%
yearm=pd.DataFrame(df.groupby('year_month').cnt.sum())
yearm
# Out:
#                 cnt
# year_month
# 2015-01      546639
# 2015-02      543594
# 2015-03      695934
# 2015-04      831582
# 2015-05      895413
# 2015-06     1033252
# 2015-07     1120687
# 2015-08     1033951
# 2015-09      892478
# 2015-10      865046
# 2015-11      677332
# 2015-12      602838
# 2016-01      582518
# 2016-02      592910
# 2016-03      656527
# 2016-04      768845
# 2016-05     1001935
# 2016-06      933878
# 2016-07     1165527
# 2016-08     1137314
# 2016-09      998619
# 2016-10      935706
# 2016-11      703859
# 2016-12      651908
# 2017-01       37680

# %%
plt.figure(figsize=(20,9))
sns.lineplot(data=yearm, x="year_month", y="cnt")
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(20,9))
sns.lineplot(data=df, x="month", y="cnt")

# %%
plt.figure(figsize=(20,9))
sns.pointplot(data=df, x="month", y="cnt")

# %%
plt.figure(figsize=(12,5))
sns.barplot(x="month", y="cnt", data=df);

# %% [markdown]
# ### 11.Plot bike shares by hours on (holidays, weekend, season)

# %%
plt.figure(figsize=(20,5))
sns.lineplot(x='hour',y='cnt', data=df, hue='is_holiday')# with lineplot (*whether it is a holiday or not*)

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x='hour',y='cnt', data=df, hue='season')  # with lineplot (*You may want to see seasonal breakdowns*)

# %%
fig, axes = plt.subplots(4, 1, figsize=(20, 16))
sns.pointplot(ax=axes[0], x='hour',y='cnt', data=df)
sns.pointplot(ax=axes[1], x='hour',y='cnt', data=df, hue='is_holiday')
sns.pointplot(ax=axes[2], x='hour',y='cnt', data=df, hue='is_weekend')
sns.pointplot(ax=axes[3], x='hour',y='cnt', data=df, hue='season')

# %% [markdown]
# ### 12.Plot bike shares by day of week
# - You may want to see whether it is a holiday or not

# %%
plt.figure(figsize=(7,4))
sns.barplot(x='day_of-week',y='cnt', data=df,hue='is_weekend')

# %%
fig, axes= plt.subplots(2, 1, figsize=(15,10))

sns.pointplot(ax=axes[0], x='day_of-week', y='cnt', data=df)
sns.pointplot(ax=axes[1], x='day_of-week', y='cnt', data=df,hue='season')

# %% [markdown]
# ### 13.Plot bike shares by day of month

# %%
a=pd.DataFrame(df.groupby('day_of-month').cnt.mean()).T
a.astype(int)
# Out:
# day_of-month    1     2     3     4     5   ...    27    28    29    30   31
# cnt           1077  1088  1127  1144  1140  ...  1130  1062  1079  1156  968
#
# [1 rows x 31 columns]

# %%
plt.figure(figsize=(15, 5))
sns.lineplot(x='day_of-month', y='cnt',data=df)
# Out:
# [day_of-month           1            2   ...           30          31
# cnt           1077.455652  1088.117754  ...  1156.406844  968.187311
#
# [1 rows x 31 columns]]

# %% [markdown]
# ### 14.Plot bike shares by year
# ### Plot bike shares on holidays by seasons

# %%
holiday=df[df.is_holiday.isin([1])]
holiday
# Out:
#                      cnt   t1   t2   hum  ...  month  year_month  dayname  month_name
# timestamp                                 ...
# 2015-04-03 00:00:00  279  8.0  6.0  82.0  ...      4     2015-04   Friday       April
# 2015-04-03 01:00:00  174  8.0  5.5  79.0  ...      4     2015-04   Friday       April
# 2015-04-03 02:00:00   89  7.5  5.5  84.5  ...      4     2015-04   Friday       April
# 2015-04-03 03:00:00   61  7.0  5.0  87.0  ...      4     2015-04   Friday       April
# 2015-04-03 04:00:00   46  7.0  6.0  93.0  ...      4     2015-04   Friday       April
# ...                  ...  ...  ...   ...  ...    ...         ...      ...         ...
# 2017-01-02 19:00:00  433  3.0  0.0  81.0  ...      1     2017-01   Monday     January
# 2017-01-02 20:00:00  334  3.0  0.0  75.0  ...      1     2017-01   Monday     January
# 2017-01-02 21:00:00  233  2.5 -0.5  78.0  ...      1     2017-01   Monday     January
# ...

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='year', y='cnt',data=df)                              # with barplot

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='season', y='cnt',data=holiday)

# %% [markdown]
# ### 15.Visualize the distribution of bike shares by weekday/weekend with piechart and barplot

# %%
df.is_weekend.value_counts()
# Out:
# 0.0    12444
# 1.0     4970
# Name: is_weekend, dtype: int64

# %%
plt.figure(figsize = (10,5))
y = df.is_weekend.value_counts().values
mylabels = ['weekday', 'weekend']
myexplode = [0.0, 0.01]
plt.pie(y, labels = mylabels,startangle = 75, explode = myexplode, autopct='%1.1f%%')

plt.show()

# %%
sns.countplot(df.is_weekend)

# %%
df1 = df.is_weekend.value_counts(normalize=True)
df1 = df1.mul(100)
df1 = df1.rename('percent').reset_index()

df1
# Out:
#    index    percent
# 0    0.0  71.459745
# 1    1.0  28.540255

# %%
fig, ax = plt.subplots(figsize=(9,7))

ax = sns.countplot(x='is_weekend',data=df)

for bar in ax.patches: 
        ax.annotate(  "%"+str(round(100*bar.get_height()/len(df),1)) +' - '+ str(bar.get_height() ), 
                    (bar.get_x()+0.20 , bar.get_height()+130) ,
                    size=12)

# %% [markdown]
# ### 16.Plot the distribution of weather code by seasons

# %%
df
# Out:
#                       cnt   t1   t2  ...  year_month  dayname  month_name
# timestamp                            ...
# 2015-01-04 00:00:00   182  3.0  2.0  ...     2015-01   Sunday     January
# 2015-01-04 01:00:00   138  3.0  2.5  ...     2015-01   Sunday     January
# 2015-01-04 02:00:00   134  2.5  2.5  ...     2015-01   Sunday     January
# 2015-01-04 03:00:00    72  2.0  2.0  ...     2015-01   Sunday     January
# 2015-01-04 04:00:00    47  2.0  0.0  ...     2015-01   Sunday     January
# ...                   ...  ...  ...  ...         ...      ...         ...
# 2017-01-03 19:00:00  1042  5.0  1.0  ...     2017-01  Tuesday     January
# 2017-01-03 20:00:00   541  5.0  1.0  ...     2017-01  Tuesday     January
# 2017-01-03 21:00:00   337  5.5  1.5  ...     2017-01  Tuesday     January
# 2017-01-03 22:00:00   224  5.5  1.5  ...     2017-01  Tuesday     January
# 2017-01-03 23:00:00   139  5.0  1.0  ...     2017-01  Tuesday     January
#
# [17414 rows x 18 columns]

# %%
df['weather_code'].astype(int)
# Out:
# timestamp
# 2015-01-04 00:00:00    3
# 2015-01-04 01:00:00    1
# 2015-01-04 02:00:00    1
# 2015-01-04 03:00:00    1
# 2015-01-04 04:00:00    1
#                       ..
# 2017-01-03 19:00:00    3
# 2017-01-03 20:00:00    4
# 2017-01-03 21:00:00    4
# 2017-01-03 22:00:00    4
# 2017-01-03 23:00:00    2
# Name: weather_code, Length: 17414, dtype: int64

# %%
sns.countplot(x='weather_code', data=df)

# %%
sns.catplot(x='weather_code', col='season',data=df, kind='count')

# %%
sns.catplot(weather_code, kind='count',col='season')

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
